# %% [markdown]
# ## Defining a tuple variable

# %%
technologies = ("Python", "Java", "Python", "C++", "JavaScript", "Python")

# %% [markdown]
# ## Print the tuple

# %%
technologies
# Out:
# ('Python', 'Java', 'Python', 'C++', 'JavaScript', 'Python')

# %% [markdown]
# ## Print type of the variable

# %%
type(technologies)
# Out:
# tuple

# %% [markdown]
# ## Print the first item

# %%
technologies[0]
# Out:
# 'Python'

# %% [markdown]
# ## Print the last item

# %%
technologies[-1]
# Out:
# 'Python'

# %% [markdown]
# ## Slice the Tuple

# %%
technologies[0:]
# Out:
# ('Python', 'Java', 'Python', 'C++', 'JavaScript', 'Python')

# %%
technologies[0:2]
# Out:
# ('Python', 'Java')

# %%
technologies[::-1]
# Out:
# ('Python', 'JavaScript', 'C++', 'Python', 'Java', 'Python')

# %% [markdown]
# ## Count Python

# %%
technologies.count("Python")
# Out:
# 3

# %% [markdown]
# ## Find the Index of C++

# %%
technologies
# Out:
# ('Python', 'Java', 'Python', 'C++', 'JavaScript', 'Python')

# %%
technologies.index("C++")
# Out:
# 3

# %% [markdown]
# ## Find the tuple Length

# %%
len(technologies)
# Out:
# 6

# %% [markdown]
# ## Convert the tuple into a list

# %%
ls_tech = list(technologies)

# %%
ls_tech
# Out:
# ['Python', 'Java', 'Python', 'C++', 'JavaScript', 'Python']

# %% [markdown]
# ## Add "Go" after converting it into a list

# %%
ls_tech
# Out:
# ['Python', 'Java', 'Python', 'C++', 'JavaScript', 'Python']

# %%
ls_tech.append("Go")

# %%
ls_tech
# Out:
# ['Python', 'Java', 'Python', 'C++', 'JavaScript', 'Python', 'Go']

# %% [markdown]
# ## Convert it back to tuple

# %%
tp_tech = tuple(ls_tech)

# %%
type(tp_tech)
# Out:
# tuple
