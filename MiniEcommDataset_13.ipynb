# %% [markdown]
# ## Declaring a variable

# %%
products = [

{

"name": "Laptop",

"price": 70000,

"brand": "Dell"

},

{

"name": "Phone",

"price": 40000,

"brand": "Samsung"

},

{

"name": "Tablet",

"price": 30000,

"brand": "Apple"

}

]

# %%
type(products)
# Out:
# list

# %% [markdown]
# ## Print all products

# %%
products
# Out:
# [{'name': 'Laptop', 'price': 70000, 'brand': 'Dell'},
#  {'name': 'Phone', 'price': 40000, 'brand': 'Samsung'},
#  {'name': 'Tablet', 'price': 30000, 'brand': 'Apple'}]

# %% [markdown]
# ## print first product

# %%
products[0]
# Out:
# {'name': 'Laptop', 'price': 70000, 'brand': 'Dell'}

# %% [markdown]
# ## print second products price

# %%
products[1]["price"]
# Out:
# 40000

# %% [markdown]
# ## print 3rd products brand

# %%
products[2]["brand"]
# Out:
# 'Apple'

# %% [markdown]
# ## Add rating to second product

# %%
products[1]["rating"]="5Star"

# %%
products
# Out:
# [{'name': 'Laptop', 'price': 70000, 'brand': 'Dell'},
#  {'name': 'Phone', 'price': 40000, 'brand': 'Samsung', 'rating': '5Star'},
#  {'name': 'Tablet', 'price': 30000, 'brand': 'Apple'}]

# %% [markdown]
# ## Add another product Manually

# %%
products.append({'name':"notebook","price":90000,"brand":"Lenovo"})

# %% [markdown]
# ## print the final dataset

# %%
products
# Out:
# [{'name': 'Laptop', 'price': 70000, 'brand': 'Dell'},
#  {'name': 'Phone', 'price': 40000, 'brand': 'Samsung', 'rating': '5Star'},
#  {'name': 'Tablet', 'price': 30000, 'brand': 'Apple'},
#  {'name': 'notebook', 'price': 90000, 'brand': 'Lenovo'}]

# %%
type(products)
# Out:
# list
