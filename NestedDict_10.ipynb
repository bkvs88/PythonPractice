# %% [markdown]
# ## Declaring Variable

# %%
employee = {

"name": "Amit",

"department": "Engineering",

"skills": {

"language": "Python",

"database": "PostgreSQL",

"cloud": "AWS"

},

"salary": 80000

}

# %%
employee
# Out:
# {'name': 'Amit',
#  'department': 'Engineering',
#  'skills': {'language': 'Python', 'database': 'PostgreSQL', 'cloud': 'AWS'},
#  'salary': 80000}

# %%
type(employee)
# Out:
# dict

# %% [markdown]
# ## Print employee name

# %%
employee.get("name")
# Out:
# 'Amit'

# %% [markdown]
# ## Print department

# %%
employee.get("department")
# Out:
# 'Engineering'

# %% [markdown]
# ## Print Complete skills dictionary

# %%
employee.get("skills")
# Out:
# {'language': 'Python', 'database': 'PostgreSQL', 'cloud': 'AWS'}

# %% [markdown]
# ## Print programming language
# ### To access values in a nested dictionary, to use chained square brackets [], where each set of brackets navigates one level deeper

# %%
employee.get("skills").get("language")
# Out:
# 'Python'

# %% [markdown]
# ## Print database using get method

# %%
employee.get("skills").get("database")
# Out:
# 'PostgreSQL'

# %% [markdown]
# ## Print cloud technology get method

# %%
employee.get("skills").get("cloud")
# Out:
# 'AWS'

# %% [markdown]
# ## Change "Python" to "Python + JavaScript" using assignment

# %%
employee["skills"]["language"]="Python + JavaScript"

# %%
employee
# Out:
# {'name': 'Amit',
#  'department': 'Engineering',
#  'skills': {'language': 'Python + JavaScript',
#   'database': 'PostgreSQL',
#   'cloud': 'AWS'},
#  'salary': 80000}

# %% [markdown]
# ## Change Salary

# %%
employee["salary"]=100000

# %%
employee
# Out:
# {'name': 'Amit',
#  'department': 'Engineering',
#  'skills': {'language': 'Python + JavaScript',
#   'database': 'PostgreSQL',
#   'cloud': 'AWS'},
#  'salary': 100000}

# %% [markdown]
# ## Add "experience" :3

# %%
employee["experience"]=3

# %%
employee
# Out:
# {'name': 'Amit',
#  'department': 'Engineering',
#  'skills': {'language': 'Python + JavaScript',
#   'database': 'PostgreSQL',
#   'cloud': 'AWS'},
#  'salary': 100000,
#  'experience': 3}

# %%
employee["skills"]["container"]="Docker"

# %%
employee
# Out:
# {'name': 'Amit',
#  'department': 'Engineering',
#  'skills': {'language': 'Python + JavaScript',
#   'database': 'PostgreSQL',
#   'cloud': 'AWS',
#   'container': 'Docker'},
#  'salary': 100000,
#  'experience': 3}

# %%
type(employee["skills"])
# Out:
# dict

# %%
employee["experience"]
# Out:
# 3
