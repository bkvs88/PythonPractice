# %%
a=5

# %%
type(a)
# Out:
# int

# %%
b=7.0

# %%
type(b)
# Out:
# float

# %%
c="Welcome to Python"

# %%
type(c)
# Out:
# str

# %%
check=True

# %%
type(check)
# Out:
# bool

# %%
ls=[1,2,3,4]

# %%
type(ls)
# Out:
# list

# %%
tp=(1,2,3,4,5,6)

# %%
type(tp)
# Out:
# tuple

# %%
st={1,2,3,4,4,4,5,5,6}

# %%
type(st)
# Out:
# set

# %%
st
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
dt={"name":"sravan","age":38,"location":"Earth"}

# %%
type(dt)
# Out:
# dict

# %%
int("100")
# Out:
# 100

# %%
float("45.67")
# Out:
# 45.67

# %%
bool(1)
# Out:
# True

# %%
list((1,2,3))
# Out:
# [1, 2, 3]

# %%
tuple([1,2,3])
# Out:
# (1, 2, 3)

# %%
set([1, 2, 2, 3])
# Out:
# {1, 2, 3}
