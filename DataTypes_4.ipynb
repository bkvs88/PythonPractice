# %% [markdown]
# ## Rules to Follow for variable naming convention
# #### Should start with Underscore or characters (Not start with numbers or any special character other than underscore)
# #### No reserved keywords shoule use as variable llike (if , else, while, class, import etc..)
# ##### To use lowercase letters for variables (best practice)

# %% [markdown]
# ### Assigning integer data type number to variable a. Python determines the data type of a variabl through a process call dynamic typing.

# %%
a=5

# %%
type(a)
# Out:
# int

# %%
calc=5+2

# %%
type(calc)
# Out:
# int

# %%
calc
# Out:
# 7

# %% [markdown]
# ### Assigning float data type number to variable b . Python determines the data type of a variable through a process call dynamic typing.

# %%
b=7.0

# %%
type(b)
# Out:
# float

# %%
add_check=7.234 + 2.2345

# %%
type(add_check)
# Out:
# float

# %%
add_check
# Out:
# 9.4685

# %%
a = 1+3j

# %%
type(a)
# Out:
# complex

# %%
a
# Out:
# (1+3j)

# %%
math_check = 2**2.0

# %%
type(math_check)
# Out:
# float

# %%
type(math_check)
# Out:
# float

# %% [markdown]
# ### Assigning string type sentence to variable c . Python determines the data type of a variable through a process call dynamic typing.

# %%
c="Welcome to Python"

# %%
type(c)
# Out:
# str

# %% [markdown]
# ### Assigning boolean type sentence to variable check . Python determines the data type of a variable through a process call dynamic typing.

# %%
check=True

# %%
type(check)
# Out:
# bool

# %%
false_check=False

# %%
type(false_check)
# Out:
# bool

# %%
check1= True | False

# %%
type(check1)
# Out:
# bool

# %%
check1
# Out:
# True

# %% [markdown]
# ### Assigning list type to variable ls . Python determines the data type of a variable through a process call dynamic typing.

# %%
ls=[1,2,3,4]

# %%
type(ls)
# Out:
# list

# %%
nested_list=[[1,2,3],[2,4,5],[1,5,6]]

# %%
type(nested_list)
# Out:
# list

# %% [markdown]
# ### Assigning tuple type to variable tp . Python determines the data type of a variable through a process call dynamic typing.

# %%
tp=(1,2,3,4,5,6)

# %%
type(tp)
# Out:
# tuple

# %%
tpl_with_list=([1,2,34,5,6],4,5,"sravan",["hi","testing"])

# %%
type(tpl_with_list)
# Out:
# tuple

# %% [markdown]
# ### Assigning set type to variable st . Python determines the data type of a variable through a process call dynamic typing.

# %%
st={1,2,3,4,4,4,5,5,6}

# %%
type(st)
# Out:
# set

# %%
st
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set_with_st={"Hi","Hello","test","Testing","Test","TEST","test","HI","Hi","Hello"}

# %%
type(set_with_st)
# Out:
# set

# %%
set_with_st
# Out:
# {'HI', 'Hello', 'Hi', 'TEST', 'Test', 'Testing', 'test'}

# %% [markdown]
# ### Assigning dictionary type to variable st . Python determines the data type of a variable through a process call dynamic typing.

# %%
dt={"name":"sravan","age":38,"location":"Earth"}

# %%
type(dt)
# Out:
# dict

# %%
dict_with_nested={"key1":"val1","key2":"val3","key4":"val5","key5":"{1,2,3,4}"}

# %%
type(dict_with_nested)
# Out:
# dict

# %% [markdown]
# #### In Python below process is called type casting, it takes a value formatted as one data type and constructs a new object of the requested data type.
# #### for all the below type casting process, python first analyzes the string text, and type cast the data type to requested integer, float or boolean etc..

# %% [markdown]
# ### int("100") converts the numeric string into the integer 100.

# %%
int("100")
# Out:
# 100

# %% [markdown]
# ### float("45.67") onverts the numeric string into the float.

# %%
float("45.67")
# Out:
# 45.67

# %% [markdown]
# ### str(500) converts integer numeric to the string

# %%
str(500)
# Out:
# '500'

# %% [markdown]
# ### bool(1) converst the string to boolean

# %%
bool(1)
# Out:
# True

# %% [markdown]
# ### converts the data to list

# %%
list((1,2,3))
# Out:
# [1, 2, 3]

# %% [markdown]
# ### converts the data to tuple

# %%
tuple([1,2,3])
# Out:
# (1, 2, 3)

# %% [markdown]
# ## converts the given list to set

# %%
set([1, 2, 2, 3])
# Out:
# {1, 2, 3}
