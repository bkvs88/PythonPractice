# %% [markdown]
# ## Create the variable for the string

# %%
student = "python programming for data science"

# %% [markdown]
# ## print the string

# %%
student
# Out:
# 'python programming for data science'

# %% [markdown]
# ## print the first character

# %%
student[0]
# Out:
# 'p'

# %% [markdown]
# ## print the last character

# %%
student[-1]
# Out:
# 'e'

# %% [markdown]
# ## print first 6 characters

# %%
student[0:6]
# Out:
# 'python'

# %% [markdown]
# ## print the last 7 characters

# %%
student[-7:]
# Out:
# 'science'

# %% [markdown]
# ## reverse the string using slicing

# %%
student[::-1]
# Out:
# 'ecneics atad rof gnimmargorp nohtyp'

# %% [markdown]
# ## convert the string to upper case

# %%
student.upper()
# Out:
# 'PYTHON PROGRAMMING FOR DATA SCIENCE'

# %% [markdown]
# ## conver the string to lower case

# %%
student.lower()
# Out:
# 'python programming for data science'

# %% [markdown]
# ## convert the string to title case using title()

# %%
student.title()
# Out:
# 'Python Programming For Data Science'

# %% [markdown]
# ## Count how many times a appears in string

# %%
student.count("a")
# Out:
# 3

# %% [markdown]
# ## Find the position of "programming"

# %%
student.index("programming")
# Out:
# 7

# %% [markdown]
# ## Replace "data science" with "artificial intelligence"

# %%
student.replace("data science","artificial intelligence")
# Out:
# 'python programming for artificial intelligence'

# %% [markdown]
# ## split the string into individual words

# %%
student.split()
# Out:
# ['python', 'programming', 'for', 'data', 'science']
