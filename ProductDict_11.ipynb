# %% [markdown]
# ## Declare a variable

# %%
laptop = {

"brand": "Dell",

"model": "XPS 15",

"price": 120000,

"ram": "16GB",

"storage": "512GB SSD",

"available": True

}

# %% [markdown]
# ## Display product

# %%
laptop
# Out:
# {'brand': 'Dell',
#  'model': 'XPS 15',
#  'price': 120000,
#  'ram': '16GB',
#  'storage': '512GB SSD',
#  'available': True}

# %% [markdown]
# ## Print Brand

# %%
laptop["brand"]
# Out:
# 'Dell'

# %% [markdown]
# ## Print Model

# %%
laptop["model"]
# Out:
# 'XPS 15'

# %% [markdown]
# ## Print Price

# %%
laptop["price"]
# Out:
# 120000

# %% [markdown]
# ## Change Price

# %%
laptop["price"]=139999

# %%
laptop
# Out:
# {'brand': 'Dell',
#  'model': 'XPS 15',
#  'price': 139999,
#  'ram': '16GB',
#  'storage': '512GB SSD',
#  'available': True}

# %% [markdown]
# ## Add processor information

# %%
laptop["processor"]="i10 AMD"

# %%
laptop
# Out:
# {'brand': 'Dell',
#  'model': 'XPS 15',
#  'price': 139999,
#  'ram': '16GB',
#  'storage': '512GB SSD',
#  'available': True,
#  'processor': 'i10 AMD'}

# %% [markdown]
# ## Add GPU information

# %%
laptop["GPU"]="nvidia"

# %%
laptop
# Out:
# {'brand': 'Dell',
#  'model': 'XPS 15',
#  'price': 139999,
#  'ram': '16GB',
#  'storage': '512GB SSD',
#  'available': True,
#  'processor': 'i10 AMD',
#  'GPU': 'nvidia'}

# %% [markdown]
# ## Change RAM to 32GB

# %%
laptop["ram"]="32GB"

# %%
laptop
# Out:
# {'brand': 'Dell',
#  'model': 'XPS 15',
#  'price': 139999,
#  'ram': '32GB',
#  'storage': '512GB SSD',
#  'available': True,
#  'processor': 'i10 AMD',
#  'GPU': 'nvidia'}

# %% [markdown]
# ## Remove "available"

# %%
laptop.pop("available")
# Out:
# True

# %%
laptop
# Out:
# {'brand': 'Dell',
#  'model': 'XPS 15',
#  'price': 139999,
#  'ram': '32GB',
#  'storage': '512GB SSD',
#  'processor': 'i10 AMD',
#  'GPU': 'nvidia'}

# %% [markdown]
# # Print all Keys

# %%
laptop.keys()
# Out:
# dict_keys(['brand', 'model', 'price', 'ram', 'storage', 'processor', 'GPU'])

# %% [markdown]
# ## Print all Values

# %%
laptop.values()
# Out:
# dict_values(['Dell', 'XPS 15', 139999, '32GB', '512GB SSD', 'i10 AMD', 'nvidia'])

# %% [markdown]
# ## print all items

# %%
laptop.items()
# Out:
# dict_items([('brand', 'Dell'), ('model', 'XPS 15'), ('price', 139999), ('ram', '32GB'), ('storage', '512GB SSD'), ('processor', 'i10 AMD'), ('GPU', 'nvidia')])

# %% [markdown]
# ## Create a second product dictionary for a mobile phone.

# %%
mobile= {'brand':"Apple","model":"iphone17","price":160000,"ram":"16GB","storage":"1TB","processor":"m3"}

# %%
mobile
# Out:
# {'brand': 'Apple',
#  'model': 'iphone17',
#  'price': 160000,
#  'ram': '16GB',
#  'storage': '1TB',
#  'processor': 'm3'}
