# %% [markdown]
# ## Declaration of variable list

# %%
cart = ["Laptop", "Mouse", "Keyboard", "Monitor", "Headphones"]

# %% [markdown]
# ## Display all products

# %%
cart
# Out:
# ['Laptop', 'Mouse', 'Keyboard', 'Monitor', 'Headphones']

# %% [markdown]
# # Access first and Last products from list

# %%
cart[0],cart[-1]
# Out:
# ('Laptop', 'Headphones')

# %% [markdown]
# ## Add new product Webcam to List

# %%
cart.append("Webcam")

# %%
cart
# Out:
# ['Laptop', 'Mouse', 'Keyboard', 'Monitor', 'Headphones', 'Webcam']

# %% [markdown]
# ## Insert "USB Hub" at index2

# %%
cart.insert(2,"USB Hub")

# %%
cart
# Out:
# ['Laptop', 'Mouse', 'USB Hub', 'Keyboard', 'Monitor', 'Headphones', 'Webcam']

# %% [markdown]
# ## Remove Mouse

# %%
cart.remove("Mouse")

# %%
cart
# Out:
# ['Laptop', 'USB Hub', 'Keyboard', 'Monitor', 'Headphones', 'Webcam']

# %% [markdown]
# ## Find the index of Monitor

# %%
cart.index("Monitor")
# Out:
# 3

# %% [markdown]
# ## Count Occurences of "laptop"

# %%
cart.count("Laptop")
# Out:
# 1

# %% [markdown]
# ## Create a copy of the cart

# %%
cart_copy = cart.copy()

# %%
cart_copy
# Out:
# ['Laptop', 'USB Hub', 'Keyboard', 'Monitor', 'Headphones', 'Webcam']

# %% [markdown]
# ## Reverse the Cart

# %%
cart[::-1]
# Out:
# ['Webcam', 'Headphones', 'Monitor', 'Keyboard', 'USB Hub', 'Laptop']

# %% [markdown]
# ## Sort the products alphabetically

# %%
cart.sort()

# %%
cart
# Out:
# ['Headphones', 'Keyboard', 'Laptop', 'Monitor', 'USB Hub', 'Webcam']

# %%
cart
# Out:
# ['Headphones', 'Keyboard', 'Laptop', 'Monitor', 'USB Hub', 'Webcam']
