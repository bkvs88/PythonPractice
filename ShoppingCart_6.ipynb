# %% [markdown]
# ## Declaration of variable list

# %%
cart = ["Laptop", "Mouse", "Keyboard", "Monitor", "Headphones"]

# %% [markdown]
# ## Display all products

# %%
cart
# Out:
# ['Laptop', 'Mouse', 'Keyboard', 'Monitor', 'Headphones']

# %% [markdown]
# # Access first and Last products from list

# %%
cart[0],cart[-1]
# Out:
# ('Laptop', 'Headphones')

# %% [markdown]
# ## Add new product Webcam to Listn using append()

# %%
cart.append("Webcam")

# %%
cart
# Out:
# ['Laptop', 'Mouse', 'Keyboard', 'Monitor', 'Headphones', 'Webcam']

# %% [markdown]
# ## Insert "USB Hub" at index2 using insert() .
# ### difference between append(),insert() and extend() .
# #### insert() adds an items at a specific position .
# #### append() always insert the element to last position in list . adds to the end as a single item.
# #### extend() merges items into the end, extend() method takes a collection and appends each individual element one by one to the end of your original list .

# %%
cart.insert(2,"USB Hub")

# %%
cart
# Out:
# ['Laptop', 'Mouse', 'USB Hub', 'Keyboard', 'Monitor', 'Headphones', 'Webcam']

# %% [markdown]
# ## Remove Mouse using remove()
# ### difference between remove and pop()
# #### remove() method used to remove the certain element , incase if given element not found throws index not found error, pop() with out any input will remove the last element from list and returns the index. pop(0) will remove the 0 index, in case if no element found it doesn't throw any error

# %%
cart.remove("Mouse")

# %%
cart
# Out:
# ['Laptop', 'USB Hub', 'Keyboard', 'Monitor', 'Headphones', 'Webcam']

# %% [markdown]
# ## Find the index of Monitor using index()

# %%
cart.index("Monitor")
# Out:
# 3

# %% [markdown]
# ## Count Occurences of "laptop" using count()

# %%
cart.count("Laptop")
# Out:
# 1

# %% [markdown]
# ## Create a copy of the cart using copy()

# %%
cart_copy = cart.copy()

# %%
cart_copy
# Out:
# ['Laptop', 'USB Hub', 'Keyboard', 'Monitor', 'Headphones', 'Webcam']

# %% [markdown]
# ## Reverse the Cart

# %%
cart[::-1]
# Out:
# ['Webcam', 'Headphones', 'Monitor', 'Keyboard', 'USB Hub', 'Laptop']

# %% [markdown]
# ## Sort the products alphabetically using sort()

# %%
cart.sort()

# %%
cart
# Out:
# ['Headphones', 'Keyboard', 'Laptop', 'Monitor', 'USB Hub', 'Webcam']

# %%
cart
# Out:
# ['Headphones', 'Keyboard', 'Laptop', 'Monitor', 'USB Hub', 'Webcam']

# %% [markdown]
# ### clear() method used to clear the elements from list and make the list empty
# ### copy() method used to copy the list from one list to another list.
# ### sort() method used to sort the list in alphabetical order.
# ### reverse() method used to reverse the list based on index.
