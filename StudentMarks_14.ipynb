# %% [markdown]
# ## Declaring a variable

# %%
marks = [78, 85, 90, 67, 88, 92, 76]

# %%
type(marks)
# Out:
# list

# %% [markdown]
# ## print the complete list

# %%
marks
# Out:
# [78, 85, 90, 67, 88, 92, 76]

# %% [markdown]
# ## print the first element using index

# %%
marks[0]
# Out:
# 78

# %% [markdown]
# ## print the last element using index

# %%
marks[-1]
# Out:
# 76

# %% [markdown]
# ## Print elements from index 2 to 5 using inded slicing

# %%
marks[2:6]
# Out:
# [90, 67, 88, 92]

# %% [markdown]
# ## Find the number of elements using len()

# %%
len(marks)
# Out:
# 7

# %% [markdown]
# ## Find Maximum Marks using max()

# %%
max(marks)
# Out:
# 92

# %% [markdown]
# ## Find minimum marks using min()

# %%
min(marks)
# Out:
# 67

# %% [markdown]
# ## Find Total marks using sum()

# %%
sum(marks)
# Out:
# 576

# %% [markdown]
# ## sort marks in ascending order

# %%
marks
# Out:
# [78, 85, 90, 67, 88, 92, 76]

# %%
marks.sort()

# %%
marks
# Out:
# [67, 76, 78, 85, 88, 90, 92]

# %% [markdown]
# ## sort marks in descending order

# %%
marks.sort(reverse=True)

# %%
marks
# Out:
# [92, 90, 88, 85, 78, 76, 67]

# %% [markdown]
# # add 95 to list using append()

# %%
marks.append(95)

# %%
marks
# Out:
# [92, 90, 88, 85, 78, 76, 67, 95]

# %% [markdown]
# ## add [81,84] using extend

# %%
marks.extend([81,84])

# %%
marks
# Out:
# [92, 90, 88, 85, 78, 76, 67, 95, 81, 84]

# %% [markdown]
# ## Remove 67 using remove()

# %%
marks.remove(67)

# %%
marks
# Out:
# [92, 90, 88, 85, 78, 76, 95, 81, 84]

# %% [markdown]
# ## Count how many times 90 occurs using count()

# %%
marks.count(90)
# Out:
# 1

# %% [markdown]
# ## Find the index of 88 using index()

# %%
marks
# Out:
# [92, 90, 88, 85, 78, 76, 95, 81, 84]

# %%
marks.index(88)
# Out:
# 2
