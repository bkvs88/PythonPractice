# %% [markdown]
# ## Variables Declaration

# %%
myname="Sravan"

# %%
age=68

# %%
city="Tampines"

# %%
company_name="GlobalBank"

# %%
curr_learning_topic="Python Variables"

# %%
exp_in_years=6.3

# %%
Like_to_Learn_Python=True

# %%
exp_salary=120000000.00

# %% [markdown]
# # Printing Variables and available options

# %% [markdown]
# ## Using F-strings

# %%
print(f"Hello, my name is {myname}")
# Out:
# Hello, my name is Sravan

# %% [markdown]
# ## Using Comma Separator

# %%
print("Hello, my name is",myname)
# Out:
# Hello, my name is Sravan

# %% [markdown]
# ## Using Format Method

# %%
print("Hello, my name is {}".format(myname))
# Out:
# Hello, my name is Sravan

# %% [markdown]
# ## Using String Concatenation

# %%
print("Hello, my name is "+myname)
# Out:
# Hello, my name is Sravan

# %% [markdown]
# # Printing type and variable value

# %%
print(f"My Name is {myname}, holding type of {type(myname)}.\nMy age is {age}, holding data type of {type(age)}.\nI live in City {city}, holding data type {type(city)}.\nI work for {company_name}, holding the data type {type(company_name)}.\nCurrently iam lerning {curr_learning_topic},holding the datatype {type(curr_learning_topic)}.\nI have total experience of {exp_in_years}, holding the data type {type(exp_in_years)}\nI like to Learn Python {Like_to_Learn_Python}, holding the data type {type(Like_to_Learn_Python)}\nAfter learning Python, My expected salary is {exp_salary}, holding the data type {type(exp_salary)}")
# Out:
# My Name is Sravan, holding type of <class 'str'>.
# My age is 68, holding data type of <class 'int'>.
# I live in City Tampines, holding data type <class 'str'>.
# I work for GlobalBank, holding the data type <class 'str'>.
# Currently iam lerning Python Variables,holding the datatype <class 'str'>.
# I have total experience of 6.3, holding the data type <class 'float'>
# I like to Learn Python True, holding the data type <class 'bool'>
# After learning Python, My expected salary is 120000000.0, holding the data type <class 'float'>
